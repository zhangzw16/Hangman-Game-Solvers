# %% [markdown]
# # Trexquant Interview Project (The Hangman Game)
#
# * Copyright Trexquant Investment LP. All Rights Reserved.
# * Redistribution of this question without written consent from Trexquant is prohibited

# %% [markdown]
# ## Instruction:
# For this coding test, your mission is to write an algorithm that plays the game of Hangman through our API server.
#
# When a user plays Hangman, the server first selects a secret word at random from a list. The server then returns a row of underscores (space separated)—one for each letter in the secret word—and asks the user to guess a letter. If the user guesses a letter that is in the word, the word is redisplayed with all instances of that letter shown in the correct positions, along with any letters correctly guessed on previous turns. If the letter does not appear in the word, the user is charged with an incorrect guess. The user keeps guessing letters until either (1) the user has correctly guessed all the letters in the word
# or (2) the user has made six incorrect guesses.
#
# You are required to write a "guess" function that takes current word (with underscores) as input and returns a guess letter. You will use the API codes below to play 1,000 Hangman games. You have the opportunity to practice before you want to start recording your game results.
#
# Your algorithm is permitted to use a training set of approximately 250,000 dictionary words. Your algorithm will be tested on an entirely disjoint set of 250,000 dictionary words. Please note that this means the words that you will ultimately be tested on do NOT appear in the dictionary that you are given. You are not permitted to use any dictionary other than the training dictionary we provided. This requirement will be strictly enforced by code review.
#
# You are provided with a basic, working algorithm. This algorithm will match the provided masked string (e.g. a _ _ l e) to all possible words in the dictionary, tabulate the frequency of letters appearing in these possible words, and then guess the letter with the highest frequency of appearence that has not already been guessed. If there are no remaining words that match then it will default back to the character frequency distribution of the entire dictionary.
#
# This benchmark strategy is successful approximately 18% of the time. Your task is to design an algorithm that significantly outperforms this benchmark.

# %%
import json
import requests
import time
import os

try:
    from urllib.parse import parse_qs, urlencode, urlparse
except ImportError:
    from urlparse import parse_qs, urlparse
    from urllib import urlencode

from requests.packages.urllib3.exceptions import InsecureRequestWarning

requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

import utils
from deeplearning.train import dl_model
# set cuda device
os.environ["CUDA_VISIBLE_DEVICES"] = "3"

# %%
class HangmanAPI(object):
    def __init__(self, access_token=None, session=None, timeout=None):
        self.hangman_url = self.determine_hangman_url()
        self.access_token = access_token
        self.session = session or requests.Session()
        self.timeout = timeout
        self.guessed_letters = []

        full_dictionary_location = "./dataset/words_250000_train.txt"
        self.n_grams = utils.build_n_gram_from_file(full_dictionary_location)
        self.dl_model = dl_model('test_one')
        
    @staticmethod
    def determine_hangman_url():
        links = ['https://trexsim.com', 'https://sg.trexsim.com']

        data = {link: 0 for link in links}

        for link in links:

            requests.get(link)

            for i in range(10):
                s = time.time()
                requests.get(link)
                data[link] = time.time() - s

        link = sorted(data.items(), key=lambda x: x[1])[0][0]
        link += '/trexsim/hangman'
        return link

    def guess(self, word): # word input example: "_ p p _ e "
        ###############################################
        # Replace with your own "guess" function here #
        ###############################################

        # clean the word so that we strip away the space characters
        # replace "_" with "." as "." indicates any character in regular expressions
        clean_word = word[::2].replace("_",".")
        len_word = len(clean_word)
        len_right_letters = len(clean_word) - clean_word.count('.')
        misses = [c for c in self.guessed_letters if c not in clean_word]
    
        if len_right_letters == 0 and len_word in utils.LETTER_ORDER_DICT:
            order = utils.LETTER_ORDER_DICT[len_word]
            for letter in order:
                if letter not in self.guessed_letters:
                    # print("first guess: ", letter)
                    return letter
                
        # # get the most common letter from the dictionary   
        
        ngram_probs = utils.get_n_gram_prob(self.n_grams, clean_word, self.guessed_letters)
        # Deep Learning way
        _, nn_probs = self.dl_model.predict(clean_word, misses)

        nn_probs = [p if chr(i+97) not in misses and chr(i+97) not in clean_word else 0.0 for i,p in enumerate(nn_probs)]
        nn_probs = [p/sum(nn_probs) for p in nn_probs]

        final_probs = nn_probs + ngram_probs
        best_char = chr(final_probs.argmax() + 97)

        return best_char


    ##########################################################
    # You'll likely not need to modify any of the code below #
    ##########################################################
                
    def start_game(self, practice=True, verbose=True):
        # reset guessed letters to empty set and current plausible dictionary to the full dictionary
        self.guessed_letters = []
                         
        response = self.request("/new_game", {"practice":practice})
        if response.get('status')=="approved":
            game_id = response.get('game_id')
            word = response.get('word')
            tries_remains = response.get('tries_remains')
            if verbose:
                print("Successfully start a new game! Game ID: {0}. # of tries remaining: {1}. Word: {2}.".format(game_id, tries_remains, word))
            while tries_remains>0:
                # get guessed letter from user code
                guess_letter = self.guess(word)
                    
                # append guessed letter to guessed letters field in hangman object
                self.guessed_letters.append(guess_letter)
                if verbose:
                    print("Guessing letter: {0}".format(guess_letter))
                    
                try:    
                    res = self.request("/guess_letter", {"request":"guess_letter", "game_id":game_id, "letter":guess_letter})
                except HangmanAPIError:
                    print('HangmanAPIError exception caught on request.')
                    continue
                except Exception as e:
                    print('Other exception caught on request.')
                    raise e
               
                if verbose:
                    print("Sever response: {0}".format(res))
                status = res.get('status')
                tries_remains = res.get('tries_remains')
                if status=="success":
                    if verbose:
                        print("Successfully finished game: {0}".format(game_id))
                    return True
                elif status=="failed":
                    reason = res.get('reason', '# of tries exceeded!')
                    if verbose:
                        print("Failed game: {0}. Because of: {1}".format(game_id, reason))
                    return False
                elif status=="ongoing":
                    word = res.get('word')
                    
        else:
            if verbose:
                print("Failed to start a new game")
        return status=="success"
        
    def my_status(self):
        return self.request("/my_status", {})
    
    def request(
            self, path, args=None, post_args=None, method=None):
        if args is None:
            args = dict()
        if post_args is not None:
            method = "POST"

        # Add `access_token` to post_args or args if it has not already been
        # included.
        if self.access_token:
            # If post_args exists, we assume that args either does not exists
            # or it does not need `access_token`.
            if post_args and "access_token" not in post_args:
                post_args["access_token"] = self.access_token
            elif "access_token" not in args:
                args["access_token"] = self.access_token

        time.sleep(0.2)

        num_retry, time_sleep = 50, 2
        for it in range(num_retry):
            try:
                response = self.session.request(
                    method or "GET",
                    self.hangman_url + path,
                    timeout=self.timeout,
                    params=args,
                    data=post_args,
                    verify=False
                )
                break
            except requests.HTTPError as e:
                response = json.loads(e.read())
                raise HangmanAPIError(response)
            except requests.exceptions.SSLError as e:
                if it + 1 == num_retry:
                    raise
                time.sleep(time_sleep)

        headers = response.headers
        if 'json' in headers['content-type']:
            result = response.json()
        elif "access_token" in parse_qs(response.text):
            query_str = parse_qs(response.text)
            if "access_token" in query_str:
                result = {"access_token": query_str["access_token"][0]}
                if "expires" in query_str:
                    result["expires"] = query_str["expires"][0]
            else:
                raise HangmanAPIError(response.json())
        else:
            raise HangmanAPIError('Maintype was not text, or querystring')

        if result and isinstance(result, dict) and result.get("error"):
            raise HangmanAPIError(result)
        return result
    
class HangmanAPIError(Exception):
    def __init__(self, result):
        self.result = result
        self.code = None
        try:
            self.type = result["error_code"]
        except (KeyError, TypeError):
            self.type = ""

        try:
            self.message = result["error_description"]
        except (KeyError, TypeError):
            try:
                self.message = result["error"]["message"]
                self.code = result["error"].get("code")
                if not self.type:
                    self.type = result["error"].get("type", "")
            except (KeyError, TypeError):
                try:
                    self.message = result["error_msg"]
                except (KeyError, TypeError):
                    self.message = result

        Exception.__init__(self, self.message)

# %% [markdown]
# # API Usage Examples

# %% [markdown]
# ## To start a new game:
# 1. Make sure you have implemented your own "guess" method.
# 2. Use the access_token that we sent you to create your HangmanAPI object.
# 3. Start a game by calling "start_game" method.
# 4. If you wish to test your function without being recorded, set "practice" parameter to 1.
# 5. Note: You have a rate limit of 20 new games per minute. DO NOT start more than 20 new games within one minute.

# %%
api = HangmanAPI(access_token="d1148c978731866897fbca6ab69a19", timeout=2000)
# Out:
# Architecture: GRU_4_1024_26
# models/GRU_4_1024_26/best_GRU_4_1024.pth
# Loaded pretrained model from: models/GRU_4_1024_26/best_GRU_4_1024.pth

# %% [markdown]
# ## Playing practice games:
# You can use the command below to play up to 100,000 practice games.

# %%
for _ in range(200):
    api.start_game(practice=1,verbose=True)
    [total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
    practice_success_rate = total_practice_successes / total_practice_runs
    print('run %d practice games out of an allotted 100,000. practice success rate so far = %.3f' % (total_practice_runs, practice_success_rate))
# Out:
# Successfully start a new game! Game ID: 1bec279180c0. # of tries remaining: 6. Word: _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '1bec279180c0', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ e _ _ e '}
# Guessing letter: r
# Sever response: {'game_id': '1bec279180c0', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ e _ _ e '}
# Guessing letter: l
# Sever response: {'game_id': '1bec279180c0', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ e _ _ e '}
# Guessing letter: t
# Sever response: {'game_id': '1bec279180c0', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ e t t e '}
# Guessing letter: u
# Sever response: {'game_id': '1bec279180c0', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ e t t e '}
# Guessing letter: o
# Sever response: {'game_id': '1bec279180c0', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ e t t e '}
# Guessing letter: a
# Sever response: {'game_id': '1bec279180c0', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ e t t e '}
# Guessing letter: n
# Sever response: {'game_id': '1bec279180c0', 'status': 'failed', 'tries_remains': 0, 'word': '_ _ e t t e '}
# Failed game: 1bec279180c0. Because of: # of tries exceeded!
# run 5 practice games out of an allotted 100,000. practice success rate so far = 0.000
# Successfully start a new game! Game ID: d11288e1fa12. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'd11288e1fa12', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'd11288e1fa12', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e r _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': 'd11288e1fa12', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e r i _ _ _ _ _ _ '}
# Guessing letter: p
# Sever response: {'game_id': 'd11288e1fa12', 'status': 'ongoing', 'tries_remains': 6, 'word': 'p e r i _ _ _ _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': 'd11288e1fa12', 'status': 'ongoing', 'tries_remains': 6, 'word': 'p e r i _ _ _ n _ _ '}
# Guessing letter: a
# Sever response: {'game_id': 'd11288e1fa12', 'status': 'ongoing', 'tries_remains': 6, 'word': 'p e r i a _ _ n a _ '}
# Guessing letter: l
# Sever response: {'game_id': 'd11288e1fa12', 'status': 'ongoing', 'tries_remains': 6, 'word': 'p e r i a _ _ n a l '}
# Guessing letter: g
# Sever response: {'game_id': 'd11288e1fa12', 'status': 'ongoing', 'tries_remains': 5, 'word': 'p e r i a _ _ n a l '}
# Guessing letter: o
# Sever response: {'game_id': 'd11288e1fa12', 'status': 'ongoing', 'tries_remains': 5, 'word': 'p e r i a _ o n a l '}
# Guessing letter: t
# Sever response: {'game_id': 'd11288e1fa12', 'status': 'ongoing', 'tries_remains': 4, 'word': 'p e r i a _ o n a l '}
# Guessing letter: s
# Sever response: {'game_id': 'd11288e1fa12', 'status': 'ongoing', 'tries_remains': 3, 'word': 'p e r i a _ o n a l '}
# Guessing letter: d
# Sever response: {'game_id': 'd11288e1fa12', 'status': 'ongoing', 'tries_remains': 2, 'word': 'p e r i a _ o n a l '}
# Guessing letter: c
# Sever response: {'game_id': 'd11288e1fa12', 'status': 'ongoing', 'tries_remains': 1, 'word': 'p e r i a _ o n a l '}
# Guessing letter: x
# Sever response: {'game_id': 'd11288e1fa12', 'status': 'success', 'tries_remains': 1, 'word': 'p e r i a x o n a l '}
# Successfully finished game: d11288e1fa12
# run 6 practice games out of an allotted 100,000. practice success rate so far = 0.167
# Successfully start a new game! Game ID: 9466a36ac4d6. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '9466a36ac4d6', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ e _ e _ _ e '}
# Guessing letter: n
# Sever response: {'game_id': '9466a36ac4d6', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ n _ _ _ e _ e n _ e '}
# Guessing letter: c
# Sever response: {'game_id': '9466a36ac4d6', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ n _ _ _ e _ e n c e '}
# Guessing letter: i
# Sever response: {'game_id': '9466a36ac4d6', 'status': 'ongoing', 'tries_remains': 6, 'word': 'i n _ _ _ e _ e n c e '}
# Guessing letter: r
# Sever response: {'game_id': '9466a36ac4d6', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i n _ _ _ e _ e n c e '}
# Guessing letter: t
# Sever response: {'game_id': '9466a36ac4d6', 'status': 'ongoing', 'tries_remains': 5, 'word': 'i n _ _ _ e t e n c e '}
# Guessing letter: h
# Sever response: {'game_id': '9466a36ac4d6', 'status': 'ongoing', 'tries_remains': 4, 'word': 'i n _ _ _ e t e n c e '}
# Guessing letter: p
# Sever response: {'game_id': '9466a36ac4d6', 'status': 'ongoing', 'tries_remains': 4, 'word': 'i n _ p p e t e n c e '}
# Guessing letter: a
# Sever response: {'game_id': '9466a36ac4d6', 'status': 'success', 'tries_remains': 4, 'word': 'i n a p p e t e n c e '}
# Successfully finished game: 9466a36ac4d6
# run 7 practice games out of an allotted 100,000. practice success rate so far = 0.286
# Successfully start a new game! Game ID: 49d0ed9f9491. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '49d0ed9f9491', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ e _ _ _ e '}
# Guessing letter: r
# Sever response: {'game_id': '49d0ed9f9491', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ e _ _ _ e '}
# Guessing letter: t
# Sever response: {'game_id': '49d0ed9f9491', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ e _ _ t e '}
# Guessing letter: i
# Sever response: {'game_id': '49d0ed9f9491', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ e _ i t e '}
# Guessing letter: n
# Sever response: {'game_id': '49d0ed9f9491', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ _ e _ i t e '}
# Guessing letter: l
# Sever response: {'game_id': '49d0ed9f9491', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ _ e l i t e '}
# Guessing letter: h
# Sever response: {'game_id': '49d0ed9f9491', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e _ _ e l i t e '}
# Guessing letter: m
# Sever response: {'game_id': '49d0ed9f9491', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ e _ _ e l i t e '}
# Guessing letter: s
# Sever response: {'game_id': '49d0ed9f9491', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ e _ _ e l i t e '}
# Guessing letter: d
# Sever response: {'game_id': '49d0ed9f9491', 'status': 'failed', 'tries_remains': 0, 'word': '_ e _ _ e l i t e '}
# Failed game: 49d0ed9f9491. Because of: # of tries exceeded!
# run 8 practice games out of an allotted 100,000. practice success rate so far = 0.250
# Successfully start a new game! Game ID: a9cabba5245d. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: i
# Sever response: {'game_id': 'a9cabba5245d', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: e
# Sever response: {'game_id': 'a9cabba5245d', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ e _ e _ _ '}
# Guessing letter: n
# Sever response: {'game_id': 'a9cabba5245d', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ e n e _ _ '}
# Guessing letter: s
# Sever response: {'game_id': 'a9cabba5245d', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ e n e s s '}
# Guessing letter: l
# Sever response: {'game_id': 'a9cabba5245d', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ l _ _ l _ _ l e n e s s '}
# Guessing letter: b
# Sever response: {'game_id': 'a9cabba5245d', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ l _ _ l _ b l e n e s s '}
# Guessing letter: a
# Sever response: {'game_id': 'a9cabba5245d', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a l _ _ l a b l e n e s s '}
# Guessing letter: u
# Sever response: {'game_id': 'a9cabba5245d', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a l _ u l a b l e n e s s '}
# Guessing letter: c
# Sever response: {'game_id': 'a9cabba5245d', 'status': 'success', 'tries_remains': 5, 'word': 'c a l c u l a b l e n e s s '}
# Successfully finished game: a9cabba5245d
# run 9 practice games out of an allotted 100,000. practice success rate so far = 0.333
# Successfully start a new game! Game ID: ae13279e9f27. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'ae13279e9f27', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ e _ '}
# Guessing letter: r
# Sever response: {'game_id': 'ae13279e9f27', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ e r '}
# Guessing letter: t
# Sever response: {'game_id': 'ae13279e9f27', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ e r '}
# Guessing letter: l
# Sever response: {'game_id': 'ae13279e9f27', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ _ e r '}
# Guessing letter: i
# Sever response: {'game_id': 'ae13279e9f27', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ _ _ e r '}
# Guessing letter: o
# Sever response: {'game_id': 'ae13279e9f27', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ o _ _ _ _ _ e r '}
# Guessing letter: n
# Sever response: {'game_id': 'ae13279e9f27', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ o _ _ _ _ _ e r '}
# Guessing letter: a
# Sever response: {'game_id': 'ae13279e9f27', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ o _ _ a _ _ e r '}
# Guessing letter: c
# Sever response: {'game_id': 'ae13279e9f27', 'status': 'ongoing', 'tries_remains': 2, 'word': 'c o _ _ a _ _ e r '}
# Guessing letter: m
# Sever response: {'game_id': 'ae13279e9f27', 'status': 'ongoing', 'tries_remains': 2, 'word': 'c o m _ a _ _ e r '}
# Guessing letter: p
# Sever response: {'game_id': 'ae13279e9f27', 'status': 'ongoing', 'tries_remains': 2, 'word': 'c o m p a _ _ e r '}
# Guessing letter: s
# Sever response: {'game_id': 'ae13279e9f27', 'status': 'success', 'tries_remains': 2, 'word': 'c o m p a s s e r '}
# Successfully finished game: ae13279e9f27
# run 10 practice games out of an allotted 100,000. practice success rate so far = 0.400
# Successfully start a new game! Game ID: 4508540f1a5c. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '4508540f1a5c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '4508540f1a5c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ i _ _ _ _ _ i _ '}
# Guessing letter: a
# Sever response: {'game_id': '4508540f1a5c', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ _ i _ _ _ _ _ i _ '}
# Guessing letter: t
# Sever response: {'game_id': '4508540f1a5c', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ t i _ _ _ _ t i _ '}
# Guessing letter: c
# Sever response: {'game_id': '4508540f1a5c', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ t i _ _ _ _ t i c '}
# Guessing letter: n
# Sever response: {'game_id': '4508540f1a5c', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a n t i _ _ _ _ t i c '}
# Guessing letter: o
# Sever response: {'game_id': '4508540f1a5c', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a n t i _ _ _ o t i c '}
# Guessing letter: y
# Sever response: {'game_id': '4508540f1a5c', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a n t i _ y _ o t i c '}
# Guessing letter: p
# Sever response: {'game_id': '4508540f1a5c', 'status': 'ongoing', 'tries_remains': 4, 'word': 'a n t i _ y _ o t i c '}
# Guessing letter: h
# Sever response: {'game_id': '4508540f1a5c', 'status': 'ongoing', 'tries_remains': 3, 'word': 'a n t i _ y _ o t i c '}
# Guessing letter: g
# Sever response: {'game_id': '4508540f1a5c', 'status': 'ongoing', 'tries_remains': 2, 'word': 'a n t i _ y _ o t i c '}
# Guessing letter: m
# Sever response: {'game_id': '4508540f1a5c', 'status': 'ongoing', 'tries_remains': 2, 'word': 'a n t i _ y m o t i c '}
# Guessing letter: z
# Sever response: {'game_id': '4508540f1a5c', 'status': 'success', 'tries_remains': 2, 'word': 'a n t i z y m o t i c '}
# Successfully finished game: 4508540f1a5c
# run 11 practice games out of an allotted 100,000. practice success rate so far = 0.455
# Successfully start a new game! Game ID: 9e080e15902c. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '9e080e15902c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '9e080e15902c', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '9e080e15902c', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ _ _ _ '}
# Guessing letter: o
# Sever response: {'game_id': '9e080e15902c', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ o _ _ _ _ o _ '}
# Guessing letter: n
# Sever response: {'game_id': '9e080e15902c', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ o _ _ _ _ o _ '}
# Guessing letter: r
# Sever response: {'game_id': '9e080e15902c', 'status': 'ongoing', 'tries_remains': 2, 'word': 'r o _ _ _ _ o _ '}
# Guessing letter: s
# Sever response: {'game_id': '9e080e15902c', 'status': 'ongoing', 'tries_remains': 1, 'word': 'r o _ _ _ _ o _ '}
# Guessing letter: t
# Sever response: {'game_id': '9e080e15902c', 'status': 'failed', 'tries_remains': 0, 'word': 'r o _ _ _ _ o _ '}
# Failed game: 9e080e15902c. Because of: # of tries exceeded!
# run 12 practice games out of an allotted 100,000. practice success rate so far = 0.417
# Successfully start a new game! Game ID: d7f0ce220648. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'd7f0ce220648', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': 'd7f0ce220648', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ i _ _ '}
# Guessing letter: n
# Sever response: {'game_id': 'd7f0ce220648', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ i _ n '}
# Guessing letter: o
# Sever response: {'game_id': 'd7f0ce220648', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ o _ _ i _ n '}
# Guessing letter: a
# Sever response: {'game_id': 'd7f0ce220648', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a _ _ o _ _ i a n '}
# Guessing letter: r
# Sever response: {'game_id': 'd7f0ce220648', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a _ _ o _ _ i a n '}
# Guessing letter: l
# Sever response: {'game_id': 'd7f0ce220648', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a _ _ o _ _ i a n '}
# Guessing letter: t
# Sever response: {'game_id': 'd7f0ce220648', 'status': 'ongoing', 'tries_remains': 3, 'word': 't a _ t o _ _ i a n '}
# Guessing letter: u
# Sever response: {'game_id': 'd7f0ce220648', 'status': 'ongoing', 'tries_remains': 3, 'word': 't a u t o u _ i a n '}
# Guessing letter: s
# Sever response: {'game_id': 'd7f0ce220648', 'status': 'success', 'tries_remains': 3, 'word': 't a u t o u s i a n '}
# Successfully finished game: d7f0ce220648
# run 13 practice games out of an allotted 100,000. practice success rate so far = 0.462
# Successfully start a new game! Game ID: f14e86cfa2a3. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'f14e86cfa2a3', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ e _ _ _ e _ '}
# Guessing letter: r
# Sever response: {'game_id': 'f14e86cfa2a3', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ e r _ _ e _ '}
# Guessing letter: t
# Sever response: {'game_id': 'f14e86cfa2a3', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ e r _ _ e _ '}
# Guessing letter: s
# Sever response: {'game_id': 'f14e86cfa2a3', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ e r _ _ e _ '}
# Guessing letter: d
# Sever response: {'game_id': 'f14e86cfa2a3', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ e r _ _ e d '}
# Guessing letter: a
# Sever response: {'game_id': 'f14e86cfa2a3', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ e r a _ e d '}
# Guessing letter: g
# Sever response: {'game_id': 'f14e86cfa2a3', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ e r a g e d '}
# Guessing letter: v
# Sever response: {'game_id': 'f14e86cfa2a3', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e v e r a g e d '}
# Guessing letter: l
# Sever response: {'game_id': 'f14e86cfa2a3', 'status': 'success', 'tries_remains': 4, 'word': 'l e v e r a g e d '}
# Successfully finished game: f14e86cfa2a3
# run 14 practice games out of an allotted 100,000. practice success rate so far = 0.500
# Successfully start a new game! Game ID: fce834104a09. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'fce834104a09', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': 'fce834104a09', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ _ _ i _ _ '}
# Guessing letter: n
# Sever response: {'game_id': 'fce834104a09', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ _ _ _ _ i _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'fce834104a09', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ r _ _ _ _ i _ _ '}
# Guessing letter: a
# Sever response: {'game_id': 'fce834104a09', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ r a _ _ _ i _ _ '}
# Guessing letter: t
# Sever response: {'game_id': 'fce834104a09', 'status': 'ongoing', 'tries_remains': 5, 'word': 't e t r a _ _ _ i _ _ '}
# Guessing letter: o
# Sever response: {'game_id': 'fce834104a09', 'status': 'ongoing', 'tries_remains': 5, 'word': 't e t r a _ o _ i _ _ '}
# Guessing letter: m
# Sever response: {'game_id': 'fce834104a09', 'status': 'ongoing', 'tries_remains': 5, 'word': 't e t r a _ o _ i _ m '}
# Guessing letter: s
# Sever response: {'game_id': 'fce834104a09', 'status': 'ongoing', 'tries_remains': 4, 'word': 't e t r a _ o _ i _ m '}
# Guessing letter: d
# Sever response: {'game_id': 'fce834104a09', 'status': 'ongoing', 'tries_remains': 3, 'word': 't e t r a _ o _ i _ m '}
# Guessing letter: u
# Sever response: {'game_id': 'fce834104a09', 'status': 'ongoing', 'tries_remains': 3, 'word': 't e t r a _ o _ i u m '}
# Guessing letter: b
# Sever response: {'game_id': 'fce834104a09', 'status': 'ongoing', 'tries_remains': 2, 'word': 't e t r a _ o _ i u m '}
# Guessing letter: c
# Sever response: {'game_id': 'fce834104a09', 'status': 'ongoing', 'tries_remains': 1, 'word': 't e t r a _ o _ i u m '}
# Guessing letter: l
# Sever response: {'game_id': 'fce834104a09', 'status': 'ongoing', 'tries_remains': 1, 'word': 't e t r a _ o l i u m '}
# Guessing letter: f
# Sever response: {'game_id': 'fce834104a09', 'status': 'failed', 'tries_remains': 0, 'word': 't e t r a _ o l i u m '}
# Failed game: fce834104a09. Because of: # of tries exceeded!
# run 15 practice games out of an allotted 100,000. practice success rate so far = 0.467
# Successfully start a new game! Game ID: da4118d8e0ff. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'da4118d8e0ff', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ e _ _ _ _ _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'da4118d8e0ff', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ r e _ _ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': 'da4118d8e0ff', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ r e _ _ _ _ _ _ i _ _ '}
# Guessing letter: n
# Sever response: {'game_id': 'da4118d8e0ff', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ r e _ _ _ _ _ _ i _ n '}
# Guessing letter: o
# Sever response: {'game_id': 'da4118d8e0ff', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ r e _ _ _ _ _ _ i o n '}
# Guessing letter: t
# Sever response: {'game_id': 'da4118d8e0ff', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ r e _ _ _ t _ t i o n '}
# Guessing letter: a
# Sever response: {'game_id': 'da4118d8e0ff', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ r e _ _ _ t a t i o n '}
# Guessing letter: p
# Sever response: {'game_id': 'da4118d8e0ff', 'status': 'ongoing', 'tries_remains': 6, 'word': 'p r e _ _ _ t a t i o n '}
# Guessing letter: u
# Sever response: {'game_id': 'da4118d8e0ff', 'status': 'ongoing', 'tries_remains': 6, 'word': 'p r e _ u _ t a t i o n '}
# Guessing letter: s
# Sever response: {'game_id': 'da4118d8e0ff', 'status': 'ongoing', 'tries_remains': 6, 'word': 'p r e _ u s t a t i o n '}
# Guessing letter: c
# Sever response: {'game_id': 'da4118d8e0ff', 'status': 'ongoing', 'tries_remains': 5, 'word': 'p r e _ u s t a t i o n '}
# Guessing letter: j
# Sever response: {'game_id': 'da4118d8e0ff', 'status': 'ongoing', 'tries_remains': 4, 'word': 'p r e _ u s t a t i o n '}
# Guessing letter: l
# Sever response: {'game_id': 'da4118d8e0ff', 'status': 'ongoing', 'tries_remains': 3, 'word': 'p r e _ u s t a t i o n '}
# Guessing letter: f
# Sever response: {'game_id': 'da4118d8e0ff', 'status': 'ongoing', 'tries_remains': 2, 'word': 'p r e _ u s t a t i o n '}
# Guessing letter: g
# Sever response: {'game_id': 'da4118d8e0ff', 'status': 'success', 'tries_remains': 2, 'word': 'p r e g u s t a t i o n '}
# Successfully finished game: da4118d8e0ff
# run 16 practice games out of an allotted 100,000. practice success rate so far = 0.500
# Successfully start a new game! Game ID: a1066547b7cb. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'a1066547b7cb', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ e _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'a1066547b7cb', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ r _ _ _ e _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': 'a1066547b7cb', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ a r _ a _ e _ _ _ '}
# Guessing letter: c
# Sever response: {'game_id': 'a1066547b7cb', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ a r _ a c e _ _ _ '}
# Guessing letter: u
# Sever response: {'game_id': 'a1066547b7cb', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ a r _ a c e _ u _ '}
# Guessing letter: o
# Sever response: {'game_id': 'a1066547b7cb', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ a r _ a c e o u _ '}
# Guessing letter: s
# Sever response: {'game_id': 'a1066547b7cb', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ a r _ a c e o u s '}
# Guessing letter: i
# Sever response: {'game_id': 'a1066547b7cb', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ a r _ a c e o u s '}
# Guessing letter: m
# Sever response: {'game_id': 'a1066547b7cb', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a r _ a c e o u s '}
# Guessing letter: t
# Sever response: {'game_id': 'a1066547b7cb', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a r _ a c e o u s '}
# Guessing letter: n
# Sever response: {'game_id': 'a1066547b7cb', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a r _ a c e o u s '}
# Guessing letter: l
# Sever response: {'game_id': 'a1066547b7cb', 'status': 'ongoing', 'tries_remains': 2, 'word': 'l a r _ a c e o u s '}
# Guessing letter: g
# Sever response: {'game_id': 'a1066547b7cb', 'status': 'ongoing', 'tries_remains': 1, 'word': 'l a r _ a c e o u s '}
# Guessing letter: b
# Sever response: {'game_id': 'a1066547b7cb', 'status': 'failed', 'tries_remains': 0, 'word': 'l a r _ a c e o u s '}
# Failed game: a1066547b7cb. Because of: # of tries exceeded!
# run 17 practice games out of an allotted 100,000. practice success rate so far = 0.471
# Successfully start a new game! Game ID: 4be94132db96. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: i
# Sever response: {'game_id': '4be94132db96', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ i _ _ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: e
# Sever response: {'game_id': '4be94132db96', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ i _ _ _ _ _ _ e _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '4be94132db96', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ i _ _ r _ _ _ e _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '4be94132db96', 'status': 'ongoing', 'tries_remains': 6, 'word': 'a _ _ _ i _ a r _ _ _ e _ _ _ _ '}
# Guessing letter: o
# Sever response: {'game_id': '4be94132db96', 'status': 'ongoing', 'tries_remains': 6, 'word': 'a _ _ _ i _ a r _ o _ e _ o _ _ '}
# Guessing letter: u
# Sever response: {'game_id': '4be94132db96', 'status': 'ongoing', 'tries_remains': 6, 'word': 'a _ _ _ i _ a r _ o _ e _ o u _ '}
# Guessing letter: s
# Sever response: {'game_id': '4be94132db96', 'status': 'ongoing', 'tries_remains': 6, 'word': 'a _ _ _ i _ a r _ o _ e _ o u s '}
# Guessing letter: n
# Sever response: {'game_id': '4be94132db96', 'status': 'ongoing', 'tries_remains': 6, 'word': 'a _ _ _ i _ a r _ o _ e n o u s '}
# Guessing letter: h
# Sever response: {'game_id': '4be94132db96', 'status': 'ongoing', 'tries_remains': 6, 'word': 'a _ _ h i _ a r _ o _ e n o u s '}
# Guessing letter: g
# Sever response: {'game_id': '4be94132db96', 'status': 'ongoing', 'tries_remains': 6, 'word': 'a _ _ h i _ a r _ o g e n o u s '}
# Guessing letter: c
# Sever response: {'game_id': '4be94132db96', 'status': 'ongoing', 'tries_remains': 6, 'word': 'a _ _ h i c a r _ o g e n o u s '}
# Guessing letter: p
# Sever response: {'game_id': '4be94132db96', 'status': 'ongoing', 'tries_remains': 6, 'word': 'a _ p h i c a r p o g e n o u s '}
# Guessing letter: m
# Sever response: {'game_id': '4be94132db96', 'status': 'success', 'tries_remains': 6, 'word': 'a m p h i c a r p o g e n o u s '}
# Successfully finished game: 4be94132db96
# run 18 practice games out of an allotted 100,000. practice success rate so far = 0.500
# Successfully start a new game! Game ID: 03d4fba56eff. # of tries remaining: 6. Word: _ _ _ _ .
# Guessing letter: a
# Sever response: {'game_id': '03d4fba56eff', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ '}
# Guessing letter: e
# Sever response: {'game_id': '03d4fba56eff', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ e '}
# Guessing letter: o
# Sever response: {'game_id': '03d4fba56eff', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ e '}
# Guessing letter: i
# Sever response: {'game_id': '03d4fba56eff', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ e '}
# Guessing letter: u
# Sever response: {'game_id': '03d4fba56eff', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ e '}
# Guessing letter: l
# Sever response: {'game_id': '03d4fba56eff', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ _ e '}
# Guessing letter: t
# Sever response: {'game_id': '03d4fba56eff', 'status': 'failed', 'tries_remains': 0, 'word': '_ _ _ e '}
# Failed game: 03d4fba56eff. Because of: # of tries exceeded!
# run 19 practice games out of an allotted 100,000. practice success rate so far = 0.474
# Successfully start a new game! Game ID: d5a065e2130c. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'd5a065e2130c', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ _ _ _ e '}
# Guessing letter: i
# Sever response: {'game_id': 'd5a065e2130c', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ i _ _ i _ e '}
# Guessing letter: n
# Sever response: {'game_id': 'd5a065e2130c', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ i n _ i _ e '}
# Guessing letter: t
# Sever response: {'game_id': 'd5a065e2130c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ i n _ i _ e '}
# Guessing letter: d
# Sever response: {'game_id': 'd5a065e2130c', 'status': 'ongoing', 'tries_remains': 5, 'word': 'd _ _ _ _ i n _ i _ e '}
# Guessing letter: a
# Sever response: {'game_id': 'd5a065e2130c', 'status': 'ongoing', 'tries_remains': 4, 'word': 'd _ _ _ _ i n _ i _ e '}
# Guessing letter: o
# Sever response: {'game_id': 'd5a065e2130c', 'status': 'ongoing', 'tries_remains': 4, 'word': 'd o _ _ _ i n _ i _ e '}
# Guessing letter: l
# Sever response: {'game_id': 'd5a065e2130c', 'status': 'ongoing', 'tries_remains': 4, 'word': 'd o l _ _ i n l i _ e '}
# Guessing letter: k
# Sever response: {'game_id': 'd5a065e2130c', 'status': 'ongoing', 'tries_remains': 4, 'word': 'd o l _ _ i n l i k e '}
# Guessing letter: u
# Sever response: {'game_id': 'd5a065e2130c', 'status': 'ongoing', 'tries_remains': 3, 'word': 'd o l _ _ i n l i k e '}
# Guessing letter: m
# Sever response: {'game_id': 'd5a065e2130c', 'status': 'ongoing', 'tries_remains': 2, 'word': 'd o l _ _ i n l i k e '}
# Guessing letter: h
# Sever response: {'game_id': 'd5a065e2130c', 'status': 'ongoing', 'tries_remains': 2, 'word': 'd o l _ h i n l i k e '}
# Guessing letter: p
# Sever response: {'game_id': 'd5a065e2130c', 'status': 'success', 'tries_remains': 2, 'word': 'd o l p h i n l i k e '}
# Successfully finished game: d5a065e2130c
# run 20 practice games out of an allotted 100,000. practice success rate so far = 0.500
# Successfully start a new game! Game ID: 45fa05745336. # of tries remaining: 6. Word: _ _ _ _ .
# Guessing letter: a
# Sever response: {'game_id': '45fa05745336', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ a '}
# Guessing letter: e
# Sever response: {'game_id': '45fa05745336', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ a '}
# Guessing letter: i
# Sever response: {'game_id': '45fa05745336', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ a '}
# Guessing letter: o
# Sever response: {'game_id': '45fa05745336', 'status': 'ongoing', 'tries_remains': 4, 'word': 'o _ _ a '}
# Guessing letter: r
# Sever response: {'game_id': '45fa05745336', 'status': 'ongoing', 'tries_remains': 3, 'word': 'o _ _ a '}
# Guessing letter: l
# Sever response: {'game_id': '45fa05745336', 'status': 'success', 'tries_remains': 3, 'word': 'o l l a '}
# Successfully finished game: 45fa05745336
# run 21 practice games out of an allotted 100,000. practice success rate so far = 0.524
# Successfully start a new game! Game ID: 250b12fe36ab. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '250b12fe36ab', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '250b12fe36ab', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ i _ '}
# Guessing letter: o
# Sever response: {'game_id': '250b12fe36ab', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ o _ _ _ _ o i _ '}
# Guessing letter: d
# Sever response: {'game_id': '250b12fe36ab', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ o _ d _ _ o i d '}
# Guessing letter: a
# Sever response: {'game_id': '250b12fe36ab', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ o _ d _ _ o i d '}
# Guessing letter: n
# Sever response: {'game_id': '250b12fe36ab', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ o n d _ _ o i d '}
# Guessing letter: y
# Sever response: {'game_id': '250b12fe36ab', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ o n d y _ o i d '}
# Guessing letter: l
# Sever response: {'game_id': '250b12fe36ab', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ o n d y l o i d '}
# Guessing letter: p
# Sever response: {'game_id': '250b12fe36ab', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ p o n d y l o i d '}
# Guessing letter: s
# Sever response: {'game_id': '250b12fe36ab', 'status': 'success', 'tries_remains': 4, 'word': 's p o n d y l o i d '}
# Successfully finished game: 250b12fe36ab
# run 22 practice games out of an allotted 100,000. practice success rate so far = 0.545
# Successfully start a new game! Game ID: 8be511c97a61. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: i
# Sever response: {'game_id': '8be511c97a61', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ i _ i _ _ _ _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '8be511c97a61', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ i _ i _ _ n _ _ _ '}
# Guessing letter: e
# Sever response: {'game_id': '8be511c97a61', 'status': 'ongoing', 'tries_remains': 6, 'word': 'e _ _ _ i _ i _ e n e _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '8be511c97a61', 'status': 'ongoing', 'tries_remains': 6, 'word': 'e _ _ _ i s i _ e n e s s '}
# Guessing letter: v
# Sever response: {'game_id': '8be511c97a61', 'status': 'ongoing', 'tries_remains': 5, 'word': 'e _ _ _ i s i _ e n e s s '}
# Guessing letter: x
# Sever response: {'game_id': '8be511c97a61', 'status': 'ongoing', 'tries_remains': 5, 'word': 'e x _ _ i s i _ e n e s s '}
# Guessing letter: c
# Sever response: {'game_id': '8be511c97a61', 'status': 'ongoing', 'tries_remains': 4, 'word': 'e x _ _ i s i _ e n e s s '}
# Guessing letter: p
# Sever response: {'game_id': '8be511c97a61', 'status': 'ongoing', 'tries_remains': 3, 'word': 'e x _ _ i s i _ e n e s s '}
# Guessing letter: u
# Sever response: {'game_id': '8be511c97a61', 'status': 'ongoing', 'tries_remains': 3, 'word': 'e x _ u i s i _ e n e s s '}
# Guessing letter: q
# Sever response: {'game_id': '8be511c97a61', 'status': 'ongoing', 'tries_remains': 3, 'word': 'e x q u i s i _ e n e s s '}
# Guessing letter: t
# Sever response: {'game_id': '8be511c97a61', 'status': 'success', 'tries_remains': 3, 'word': 'e x q u i s i t e n e s s '}
# Successfully finished game: 8be511c97a61
# run 23 practice games out of an allotted 100,000. practice success rate so far = 0.565
# Successfully start a new game! Game ID: dfd1837f88d9. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'dfd1837f88d9', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': 'dfd1837f88d9', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': 'dfd1837f88d9', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a _ _ _ _ _ _ _ '}
# Guessing letter: o
# Sever response: {'game_id': 'dfd1837f88d9', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a _ _ _ _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'dfd1837f88d9', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ a r _ _ r _ _ _ '}
# Guessing letter: t
# Sever response: {'game_id': 'dfd1837f88d9', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a r _ _ r _ _ _ '}
# Guessing letter: u
# Sever response: {'game_id': 'dfd1837f88d9', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ a r _ _ r u _ _ '}
# Guessing letter: h
# Sever response: {'game_id': 'dfd1837f88d9', 'status': 'ongoing', 'tries_remains': 2, 'word': 'h a r _ _ r u _ _ '}
# Guessing letter: d
# Sever response: {'game_id': 'dfd1837f88d9', 'status': 'ongoing', 'tries_remains': 2, 'word': 'h a r d _ r u _ _ '}
# Guessing letter: s
# Sever response: {'game_id': 'dfd1837f88d9', 'status': 'ongoing', 'tries_remains': 1, 'word': 'h a r d _ r u _ _ '}
# Guessing letter: b
# Sever response: {'game_id': 'dfd1837f88d9', 'status': 'failed', 'tries_remains': 0, 'word': 'h a r d _ r u _ _ '}
# Failed game: dfd1837f88d9. Because of: # of tries exceeded!
# run 24 practice games out of an allotted 100,000. practice success rate so far = 0.542
# Successfully start a new game! Game ID: 88762dcafacf. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '88762dcafacf', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '88762dcafacf', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ i _ i _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '88762dcafacf', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ _ _ i _ i _ _ '}
# Guessing letter: t
# Sever response: {'game_id': '88762dcafacf', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ _ _ i t i _ _ '}
# Guessing letter: s
# Sever response: {'game_id': '88762dcafacf', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ _ _ i t i s _ '}
# Guessing letter: m
# Sever response: {'game_id': '88762dcafacf', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ _ _ i t i s m '}
# Guessing letter: r
# Sever response: {'game_id': '88762dcafacf', 'status': 'ongoing', 'tries_remains': 5, 'word': 'r e _ _ _ _ i t i s m '}
# Guessing letter: l
# Sever response: {'game_id': '88762dcafacf', 'status': 'ongoing', 'tries_remains': 4, 'word': 'r e _ _ _ _ i t i s m '}
# Guessing letter: a
# Sever response: {'game_id': '88762dcafacf', 'status': 'ongoing', 'tries_remains': 4, 'word': 'r e _ _ a _ i t i s m '}
# Guessing letter: u
# Sever response: {'game_id': '88762dcafacf', 'status': 'ongoing', 'tries_remains': 3, 'word': 'r e _ _ a _ i t i s m '}
# Guessing letter: c
# Sever response: {'game_id': '88762dcafacf', 'status': 'ongoing', 'tries_remains': 3, 'word': 'r e c _ a _ i t i s m '}
# Guessing letter: h
# Sever response: {'game_id': '88762dcafacf', 'status': 'ongoing', 'tries_remains': 3, 'word': 'r e c h a _ i t i s m '}
# Guessing letter: d
# Sever response: {'game_id': '88762dcafacf', 'status': 'ongoing', 'tries_remains': 2, 'word': 'r e c h a _ i t i s m '}
# Guessing letter: b
# Sever response: {'game_id': '88762dcafacf', 'status': 'success', 'tries_remains': 2, 'word': 'r e c h a b i t i s m '}
# Successfully finished game: 88762dcafacf
# run 25 practice games out of an allotted 100,000. practice success rate so far = 0.560
# Successfully start a new game! Game ID: c776debefaef. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'c776debefaef', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ e _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'c776debefaef', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ e _ _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': 'c776debefaef', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ e n _ _ _ '}
# Guessing letter: t
# Sever response: {'game_id': 'c776debefaef', 'status': 'ongoing', 'tries_remains': 5, 'word': 't e _ _ e n t _ _ '}
# Guessing letter: m
# Sever response: {'game_id': 'c776debefaef', 'status': 'ongoing', 'tries_remains': 5, 'word': 't e _ m e n t _ m '}
# Guessing letter: u
# Sever response: {'game_id': 'c776debefaef', 'status': 'ongoing', 'tries_remains': 5, 'word': 't e _ m e n t u m '}
# Guessing letter: g
# Sever response: {'game_id': 'c776debefaef', 'status': 'success', 'tries_remains': 5, 'word': 't e g m e n t u m '}
# Successfully finished game: c776debefaef
# run 26 practice games out of an allotted 100,000. practice success rate so far = 0.577
# Successfully start a new game! Game ID: 1bb6fabefbbd. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '1bb6fabefbbd', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '1bb6fabefbbd', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ i _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '1bb6fabefbbd', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ n _ _ i _ n '}
# Guessing letter: a
# Sever response: {'game_id': '1bb6fabefbbd', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ n _ _ i _ n '}
# Guessing letter: o
# Sever response: {'game_id': '1bb6fabefbbd', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ n _ _ i o n '}
# Guessing letter: t
# Sever response: {'game_id': '1bb6fabefbbd', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ n _ t i o n '}
# Guessing letter: c
# Sever response: {'game_id': '1bb6fabefbbd', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ n c t i o n '}
# Guessing letter: u
# Sever response: {'game_id': '1bb6fabefbbd', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ u n c t i o n '}
# Guessing letter: f
# Sever response: {'game_id': '1bb6fabefbbd', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ u n c t i o n '}
# Guessing letter: p
# Sever response: {'game_id': '1bb6fabefbbd', 'status': 'success', 'tries_remains': 3, 'word': 'p u n c t i o n '}
# Successfully finished game: 1bb6fabefbbd
# run 27 practice games out of an allotted 100,000. practice success rate so far = 0.593
# Successfully start a new game! Game ID: 1d2c6f811917. # of tries remaining: 6. Word: _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '1d2c6f811917', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ e _ '}
# Guessing letter: r
# Sever response: {'game_id': '1d2c6f811917', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ e _ '}
# Guessing letter: l
# Sever response: {'game_id': '1d2c6f811917', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e _ _ e _ '}
# Guessing letter: n
# Sever response: {'game_id': '1d2c6f811917', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e _ _ e _ '}
# Guessing letter: t
# Sever response: {'game_id': '1d2c6f811917', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ e _ _ e _ '}
# Guessing letter: s
# Sever response: {'game_id': '1d2c6f811917', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ e _ _ e s '}
# Guessing letter: i
# Sever response: {'game_id': '1d2c6f811917', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ e _ _ e s '}
# Guessing letter: d
# Sever response: {'game_id': '1d2c6f811917', 'status': 'failed', 'tries_remains': 0, 'word': '_ e _ _ e s '}
# Failed game: 1d2c6f811917. Because of: # of tries exceeded!
# run 28 practice games out of an allotted 100,000. practice success rate so far = 0.571
# Successfully start a new game! Game ID: 7828e63df517. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '7828e63df517', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '7828e63df517', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '7828e63df517', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ _ _ '}
# Guessing letter: o
# Sever response: {'game_id': '7828e63df517', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ o _ _ o _ '}
# Guessing letter: r
# Sever response: {'game_id': '7828e63df517', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ o _ _ o _ '}
# Guessing letter: n
# Sever response: {'game_id': '7828e63df517', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ o _ _ o _ '}
# Guessing letter: s
# Sever response: {'game_id': '7828e63df517', 'status': 'ongoing', 'tries_remains': 1, 'word': 's _ o _ _ o _ '}
# Guessing letter: t
# Sever response: {'game_id': '7828e63df517', 'status': 'failed', 'tries_remains': 0, 'word': 's _ o _ _ o _ '}
# Failed game: 7828e63df517. Because of: # of tries exceeded!
# run 29 practice games out of an allotted 100,000. practice success rate so far = 0.552
# Successfully start a new game! Game ID: d6113efb865c. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'd6113efb865c', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ e _ _ '}
# Guessing letter: r
# Sever response: {'game_id': 'd6113efb865c', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ e _ _ '}
# Guessing letter: s
# Sever response: {'game_id': 'd6113efb865c', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ e _ _ '}
# Guessing letter: n
# Sever response: {'game_id': 'd6113efb865c', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ e _ _ '}
# Guessing letter: l
# Sever response: {'game_id': 'd6113efb865c', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ l _ _ e _ _ '}
# Guessing letter: a
# Sever response: {'game_id': 'd6113efb865c', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ l a _ e a _ '}
# Guessing letter: c
# Sever response: {'game_id': 'd6113efb865c', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ l a _ e a _ '}
# Guessing letter: t
# Sever response: {'game_id': 'd6113efb865c', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ l a t e a _ '}
# Guessing letter: u
# Sever response: {'game_id': 'd6113efb865c', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ l a t e a u '}
# Guessing letter: p
# Sever response: {'game_id': 'd6113efb865c', 'status': 'success', 'tries_remains': 2, 'word': 'p l a t e a u '}
# Successfully finished game: d6113efb865c
# run 30 practice games out of an allotted 100,000. practice success rate so far = 0.567
# Successfully start a new game! Game ID: 1c4dc5f28509. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '1c4dc5f28509', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '1c4dc5f28509', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ i _ _ _ _ i _ '}
# Guessing letter: a
# Sever response: {'game_id': '1c4dc5f28509', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a _ _ i _ _ _ _ i _ '}
# Guessing letter: n
# Sever response: {'game_id': '1c4dc5f28509', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a n _ i _ _ _ n i n '}
# Guessing letter: t
# Sever response: {'game_id': '1c4dc5f28509', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a n _ i _ t _ n i n '}
# Guessing letter: o
# Sever response: {'game_id': '1c4dc5f28509', 'status': 'ongoing', 'tries_remains': 5, 'word': 'a n _ i o t o n i n '}
# Guessing letter: g
# Sever response: {'game_id': '1c4dc5f28509', 'status': 'success', 'tries_remains': 5, 'word': 'a n g i o t o n i n '}
# Successfully finished game: 1c4dc5f28509
# run 31 practice games out of an allotted 100,000. practice success rate so far = 0.581
# Successfully start a new game! Game ID: 1b5fddf7c704. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '1b5fddf7c704', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '1b5fddf7c704', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '1b5fddf7c704', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ a _ '}
# Guessing letter: o
# Sever response: {'game_id': '1b5fddf7c704', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ o _ a _ '}
# Guessing letter: l
# Sever response: {'game_id': '1b5fddf7c704', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ o _ a _ '}
# Guessing letter: r
# Sever response: {'game_id': '1b5fddf7c704', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ o _ a r '}
# Guessing letter: u
# Sever response: {'game_id': '1b5fddf7c704', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ o _ a r '}
# Guessing letter: c
# Sever response: {'game_id': '1b5fddf7c704', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ _ o _ a r '}
# Guessing letter: n
# Sever response: {'game_id': '1b5fddf7c704', 'status': 'failed', 'tries_remains': 0, 'word': '_ _ _ o _ a r '}
# Failed game: 1b5fddf7c704. Because of: # of tries exceeded!
# run 32 practice games out of an allotted 100,000. practice success rate so far = 0.562
# Successfully start a new game! Game ID: 1d9c5c2cae19. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '1d9c5c2cae19', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ e _ '}
# Guessing letter: r
# Sever response: {'game_id': '1d9c5c2cae19', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ e _ '}
# Guessing letter: s
# Sever response: {'game_id': '1d9c5c2cae19', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ e _ '}
# Guessing letter: d
# Sever response: {'game_id': '1d9c5c2cae19', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ _ e d '}
# Guessing letter: t
# Sever response: {'game_id': '1d9c5c2cae19', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ _ _ e d '}
# Guessing letter: n
# Sever response: {'game_id': '1d9c5c2cae19', 'status': 'ongoing', 'tries_remains': 3, 'word': 'n _ _ _ _ n e d '}
# Guessing letter: o
# Sever response: {'game_id': '1d9c5c2cae19', 'status': 'ongoing', 'tries_remains': 2, 'word': 'n _ _ _ _ n e d '}
# Guessing letter: i
# Sever response: {'game_id': '1d9c5c2cae19', 'status': 'ongoing', 'tries_remains': 2, 'word': 'n _ _ _ i n e d '}
# Guessing letter: a
# Sever response: {'game_id': '1d9c5c2cae19', 'status': 'ongoing', 'tries_remains': 2, 'word': 'n a _ _ i n e d '}
# Guessing letter: l
# Sever response: {'game_id': '1d9c5c2cae19', 'status': 'ongoing', 'tries_remains': 1, 'word': 'n a _ _ i n e d '}
# Guessing letter: m
# Sever response: {'game_id': '1d9c5c2cae19', 'status': 'failed', 'tries_remains': 0, 'word': 'n a _ _ i n e d '}
# Failed game: 1d9c5c2cae19. Because of: # of tries exceeded!
# run 33 practice games out of an allotted 100,000. practice success rate so far = 0.545
# Successfully start a new game! Game ID: 304bb53ff651. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: i
# Sever response: {'game_id': '304bb53ff651', 'status': 'ongoing', 'tries_remains': 6, 'word': 'i _ _ _ _ _ _ _ _ i _ _ _ '}
# Guessing letter: n
# ...
# Guessing letter: d
# Sever response: {'game_id': '0c08df563bdb', 'status': 'success', 'tries_remains': 6, 'word': 's y n c h o n d r o s i s '}
# Successfully finished game: 0c08df563bdb
# run 194 practice games out of an allotted 100,000. practice success rate so far = 0.675
# Successfully start a new game! Game ID: d301ae186049. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'd301ae186049', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ e _ _ _ e '}
# Guessing letter: r
# Sever response: {'game_id': 'd301ae186049', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ _ e _ _ _ e '}
# Guessing letter: l
# Sever response: {'game_id': 'd301ae186049', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e _ _ l e _ _ _ e '}
# Guessing letter: t
# Sever response: {'game_id': 'd301ae186049', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e t t l e _ _ _ e '}
# Guessing letter: s
# Sever response: {'game_id': 'd301ae186049', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ e t t l e _ _ s e '}
# Guessing letter: i
# Sever response: {'game_id': 'd301ae186049', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ e t t l e _ _ s e '}
# Guessing letter: o
# Sever response: {'game_id': 'd301ae186049', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ e t t l e _ _ s e '}
# Guessing letter: n
# Sever response: {'game_id': 'd301ae186049', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ e t t l e _ _ s e '}
# Guessing letter: a
# Sever response: {'game_id': 'd301ae186049', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ e t t l e _ a s e '}
# Guessing letter: m
# Sever response: {'game_id': 'd301ae186049', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ e t t l e _ a s e '}
# Guessing letter: b
# Sever response: {'game_id': 'd301ae186049', 'status': 'failed', 'tries_remains': 0, 'word': '_ e t t l e _ a s e '}
# Failed game: d301ae186049. Because of: # of tries exceeded!
# run 195 practice games out of an allotted 100,000. practice success rate so far = 0.672
# Successfully start a new game! Game ID: bbfade73d93f. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: i
# Sever response: {'game_id': 'bbfade73d93f', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ _ _ _ _ _ _ i _ '}
# Guessing letter: o
# Sever response: {'game_id': 'bbfade73d93f', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ _ _ _ _ i _ '}
# Guessing letter: e
# Sever response: {'game_id': 'bbfade73d93f', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ e _ _ e _ _ _ _ i _ '}
# Guessing letter: r
# Sever response: {'game_id': 'bbfade73d93f', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ r e _ _ e _ _ _ _ i _ '}
# Guessing letter: a
# Sever response: {'game_id': 'bbfade73d93f', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ r e _ _ e _ _ a _ i _ '}
# Guessing letter: c
# Sever response: {'game_id': 'bbfade73d93f', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ r e _ c e _ _ a _ i c '}
# Guessing letter: p
# Sever response: {'game_id': 'bbfade73d93f', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ r e _ c e p _ a _ i c '}
# Guessing letter: h
# Sever response: {'game_id': 'bbfade73d93f', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ r e _ c e p h a _ i c '}
# Guessing letter: l
# Sever response: {'game_id': 'bbfade73d93f', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ r e _ c e p h a l i c '}
# Guessing letter: n
# Sever response: {'game_id': 'bbfade73d93f', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ r e n c e p h a l i c '}
# Guessing letter: t
# Sever response: {'game_id': 'bbfade73d93f', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ r e n c e p h a l i c '}
# Guessing letter: s
# Sever response: {'game_id': 'bbfade73d93f', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ r e n c e p h a l i c '}
# Guessing letter: d
# Sever response: {'game_id': 'bbfade73d93f', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ r e n c e p h a l i c '}
# Guessing letter: f
# Sever response: {'game_id': 'bbfade73d93f', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ _ r e n c e p h a l i c '}
# Guessing letter: u
# Sever response: {'game_id': 'bbfade73d93f', 'status': 'failed', 'tries_remains': 0, 'word': '_ _ r e n c e p h a l i c '}
# Failed game: bbfade73d93f. Because of: # of tries exceeded!
# run 196 practice games out of an allotted 100,000. practice success rate so far = 0.668
# Successfully start a new game! Game ID: b1ff130b5322. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: i
# Sever response: {'game_id': 'b1ff130b5322', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ i _ _ _ _ _ _ i _ '}
# Guessing letter: t
# Sever response: {'game_id': 'b1ff130b5322', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ i _ _ _ _ _ t i _ '}
# Guessing letter: c
# Sever response: {'game_id': 'b1ff130b5322', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ i _ _ _ _ _ t i c '}
# Guessing letter: a
# Sever response: {'game_id': 'b1ff130b5322', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ i _ _ _ a _ t i c '}
# Guessing letter: s
# Sever response: {'game_id': 'b1ff130b5322', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ i _ _ _ a s t i c '}
# Guessing letter: l
# Sever response: {'game_id': 'b1ff130b5322', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ i _ _ _ a s t i c '}
# Guessing letter: o
# Sever response: {'game_id': 'b1ff130b5322', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ i _ _ _ a s t i c '}
# Guessing letter: p
# Sever response: {'game_id': 'b1ff130b5322', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ p _ _ i p _ _ a s t i c '}
# Guessing letter: h
# Sever response: {'game_id': 'b1ff130b5322', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ p _ _ i p h _ a s t i c '}
# Guessing letter: r
# Sever response: {'game_id': 'b1ff130b5322', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ p _ r i p h r a s t i c '}
# Guessing letter: e
# Sever response: {'game_id': 'b1ff130b5322', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ p e r i p h r a s t i c '}
# Guessing letter: u
# Sever response: {'game_id': 'b1ff130b5322', 'status': 'ongoing', 'tries_remains': 4, 'word': 'u _ p e r i p h r a s t i c '}
# Guessing letter: n
# Sever response: {'game_id': 'b1ff130b5322', 'status': 'success', 'tries_remains': 4, 'word': 'u n p e r i p h r a s t i c '}
# Successfully finished game: b1ff130b5322
# run 197 practice games out of an allotted 100,000. practice success rate so far = 0.670
# Successfully start a new game! Game ID: 92273a7f42de. # of tries remaining: 6. Word: _ _ _ _ _ .
# Guessing letter: s
# Sever response: {'game_id': '92273a7f42de', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ '}
# Guessing letter: e
# Sever response: {'game_id': '92273a7f42de', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ e '}
# Guessing letter: r
# Sever response: {'game_id': '92273a7f42de', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ e '}
# Guessing letter: l
# Sever response: {'game_id': '92273a7f42de', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ e '}
# Guessing letter: t
# Sever response: {'game_id': '92273a7f42de', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ _ _ _ e '}
# Guessing letter: n
# Sever response: {'game_id': '92273a7f42de', 'status': 'ongoing', 'tries_remains': 2, 'word': 'n _ _ n e '}
# Guessing letter: o
# Sever response: {'game_id': '92273a7f42de', 'status': 'success', 'tries_remains': 2, 'word': 'n o o n e '}
# Successfully finished game: 92273a7f42de
# run 198 practice games out of an allotted 100,000. practice success rate so far = 0.672
# Successfully start a new game! Game ID: af25db2afbad. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': 'af25db2afbad', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ e _ _ _ _ e e _ '}
# Guessing letter: r
# Sever response: {'game_id': 'af25db2afbad', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ r e _ _ _ _ e e _ '}
# Guessing letter: n
# Sever response: {'game_id': 'af25db2afbad', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ r e _ _ _ _ e e _ '}
# Guessing letter: s
# Sever response: {'game_id': 'af25db2afbad', 'status': 'ongoing', 'tries_remains': 5, 'word': 's _ r e _ _ s _ e e _ '}
# Guessing letter: t
# Sever response: {'game_id': 'af25db2afbad', 'status': 'ongoing', 'tries_remains': 5, 'word': 's _ r e _ _ s _ e e t '}
# Guessing letter: h
# Sever response: {'game_id': 'af25db2afbad', 'status': 'ongoing', 'tries_remains': 5, 'word': 's _ r e _ _ s h e e t '}
# Guessing letter: a
# Sever response: {'game_id': 'af25db2afbad', 'status': 'ongoing', 'tries_remains': 5, 'word': 's _ r e a _ s h e e t '}
# Guessing letter: d
# Sever response: {'game_id': 'af25db2afbad', 'status': 'ongoing', 'tries_remains': 5, 'word': 's _ r e a d s h e e t '}
# Guessing letter: p
# Sever response: {'game_id': 'af25db2afbad', 'status': 'success', 'tries_remains': 5, 'word': 's p r e a d s h e e t '}
# Successfully finished game: af25db2afbad
# run 199 practice games out of an allotted 100,000. practice success rate so far = 0.673
# Successfully start a new game! Game ID: fb08e0dc6f50. # of tries remaining: 6. Word: _ _ _ _ .
# Guessing letter: a
# Sever response: {'game_id': 'fb08e0dc6f50', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ '}
# Guessing letter: e
# Sever response: {'game_id': 'fb08e0dc6f50', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ '}
# Guessing letter: o
# Sever response: {'game_id': 'fb08e0dc6f50', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': 'fb08e0dc6f50', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ _ _ i '}
# Guessing letter: u
# Sever response: {'game_id': 'fb08e0dc6f50', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ u _ i '}
# Guessing letter: r
# Sever response: {'game_id': 'fb08e0dc6f50', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ u _ i '}
# Guessing letter: t
# Sever response: {'game_id': 'fb08e0dc6f50', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ u _ i '}
# Guessing letter: l
# Sever response: {'game_id': 'fb08e0dc6f50', 'status': 'failed', 'tries_remains': 0, 'word': '_ u _ i '}
# Failed game: fb08e0dc6f50. Because of: # of tries exceeded!
# run 200 practice games out of an allotted 100,000. practice success rate so far = 0.670
# Successfully start a new game! Game ID: 61332744a3a4. # of tries remaining: 6. Word: _ _ _ _ _ .
# Guessing letter: s
# Sever response: {'game_id': '61332744a3a4', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ '}
# Guessing letter: e
# Sever response: {'game_id': '61332744a3a4', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ _ _ '}
# Guessing letter: a
# Sever response: {'game_id': '61332744a3a4', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ a _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '61332744a3a4', 'status': 'ongoing', 'tries_remains': 4, 'word': 'r a _ _ _ '}
# Guessing letter: n
# Sever response: {'game_id': '61332744a3a4', 'status': 'ongoing', 'tries_remains': 3, 'word': 'r a _ _ _ '}
# Guessing letter: t
# Sever response: {'game_id': '61332744a3a4', 'status': 'ongoing', 'tries_remains': 2, 'word': 'r a _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '61332744a3a4', 'status': 'ongoing', 'tries_remains': 1, 'word': 'r a _ _ _ '}
# Guessing letter: l
# Sever response: {'game_id': '61332744a3a4', 'status': 'ongoing', 'tries_remains': 1, 'word': 'r a _ _ l '}
# Guessing letter: o
# Sever response: {'game_id': '61332744a3a4', 'status': 'ongoing', 'tries_remains': 1, 'word': 'r a o _ l '}
# Guessing letter: u
# Sever response: {'game_id': '61332744a3a4', 'status': 'success', 'tries_remains': 1, 'word': 'r a o u l '}
# Successfully finished game: 61332744a3a4
# run 201 practice games out of an allotted 100,000. practice success rate so far = 0.672
# Successfully start a new game! Game ID: 042fc803b70c. # of tries remaining: 6. Word: _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '042fc803b70c', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ e _ _ _ _ '}
# Guessing letter: r
# Sever response: {'game_id': '042fc803b70c', 'status': 'ongoing', 'tries_remains': 6, 'word': 'r e _ _ r _ '}
# Guessing letter: a
# Sever response: {'game_id': '042fc803b70c', 'status': 'ongoing', 'tries_remains': 5, 'word': 'r e _ _ r _ '}
# Guessing letter: o
# Sever response: {'game_id': '042fc803b70c', 'status': 'ongoing', 'tries_remains': 5, 'word': 'r e _ o r _ '}
# Guessing letter: t
# Sever response: {'game_id': '042fc803b70c', 'status': 'ongoing', 'tries_remains': 4, 'word': 'r e _ o r _ '}
# Guessing letter: n
# Sever response: {'game_id': '042fc803b70c', 'status': 'ongoing', 'tries_remains': 4, 'word': 'r e _ o r n '}
# Guessing letter: c
# Sever response: {'game_id': '042fc803b70c', 'status': 'ongoing', 'tries_remains': 3, 'word': 'r e _ o r n '}
# Guessing letter: w
# Sever response: {'game_id': '042fc803b70c', 'status': 'ongoing', 'tries_remains': 2, 'word': 'r e _ o r n '}
# Guessing letter: b
# Sever response: {'game_id': '042fc803b70c', 'status': 'success', 'tries_remains': 2, 'word': 'r e b o r n '}
# Successfully finished game: 042fc803b70c
# run 202 practice games out of an allotted 100,000. practice success rate so far = 0.673
# Successfully start a new game! Game ID: 13eaa4b5ad17. # of tries remaining: 6. Word: _ _ _ _ _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '13eaa4b5ad17', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ _ _ _ _ e _ _ _ e e '}
# Guessing letter: r
# Sever response: {'game_id': '13eaa4b5ad17', 'status': 'ongoing', 'tries_remains': 6, 'word': '_ r _ _ _ e _ _ r e e '}
# Guessing letter: t
# Sever response: {'game_id': '13eaa4b5ad17', 'status': 'ongoing', 'tries_remains': 6, 'word': 't r _ _ _ e t t r e e '}
# Guessing letter: u
# Sever response: {'game_id': '13eaa4b5ad17', 'status': 'ongoing', 'tries_remains': 6, 'word': 't r u _ _ e t t r e e '}
# Guessing letter: m
# Sever response: {'game_id': '13eaa4b5ad17', 'status': 'ongoing', 'tries_remains': 6, 'word': 't r u m _ e t t r e e '}
# Guessing letter: p
# Sever response: {'game_id': '13eaa4b5ad17', 'status': 'success', 'tries_remains': 6, 'word': 't r u m p e t t r e e '}
# Successfully finished game: 13eaa4b5ad17
# run 203 practice games out of an allotted 100,000. practice success rate so far = 0.675
# Successfully start a new game! Game ID: 482902f02ec6. # of tries remaining: 6. Word: _ _ _ _ _ _ _ .
# Guessing letter: e
# Sever response: {'game_id': '482902f02ec6', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ _ _ '}
# Guessing letter: i
# Sever response: {'game_id': '482902f02ec6', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ _ _ i _ '}
# Guessing letter: a
# Sever response: {'game_id': '482902f02ec6', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ a _ i a '}
# Guessing letter: r
# Sever response: {'game_id': '482902f02ec6', 'status': 'ongoing', 'tries_remains': 5, 'word': '_ _ _ a r i a '}
# Guessing letter: l
# Sever response: {'game_id': '482902f02ec6', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ _ _ a r i a '}
# Guessing letter: o
# Sever response: {'game_id': '482902f02ec6', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ o _ a r i a '}
# Guessing letter: n
# Sever response: {'game_id': '482902f02ec6', 'status': 'ongoing', 'tries_remains': 4, 'word': '_ o n a r i a '}
# Guessing letter: m
# Sever response: {'game_id': '482902f02ec6', 'status': 'ongoing', 'tries_remains': 3, 'word': '_ o n a r i a '}
# Guessing letter: t
# Sever response: {'game_id': '482902f02ec6', 'status': 'ongoing', 'tries_remains': 2, 'word': '_ o n a r i a '}
# Guessing letter: d
# Sever response: {'game_id': '482902f02ec6', 'status': 'ongoing', 'tries_remains': 1, 'word': '_ o n a r i a '}
# Guessing letter: c
# Sever response: {'game_id': '482902f02ec6', 'status': 'failed', 'tries_remains': 0, 'word': '_ o n a r i a '}
# Failed game: 482902f02ec6. Because of: # of tries exceeded!
# run 204 practice games out of an allotted 100,000. practice success rate so far = 0.672

# %% [markdown]
# ## Playing recorded games:
# Please finalize your code prior to running the cell below. Once this code executes once successfully your submission will be finalized. Our system will not allow you to rerun any additional games.
#
# Please note that it is expected that after you successfully run this block of code that subsequent runs will result in the error message "Your account has been deactivated".
#
# Once you've run this section of the code your submission is complete. Please send us your source code via email.

# %%
for i in range(1000):
    print('Playing ', i, ' th game')
    # Uncomment the following line to execute your final runs. Do not do this until you are satisfied with your submission
    api.start_game(practice=0,verbose=False)
    
    # DO NOT REMOVE as otherwise the server may lock you out for too high frequency of requests
    time.sleep(0.5)
# Out:
# Playing  0  th game
# Playing  1  th game
# Playing  2  th game
# Playing  3  th game
# Playing  4  th game
# Playing  5  th game
# Playing  6  th game
# Playing  7  th game
# Playing  8  th game
# Playing  9  th game
# Playing  10  th game
# Playing  11  th game
# Playing  12  th game
# Playing  13  th game
# Playing  14  th game
# Playing  15  th game
# Playing  16  th game
# Playing  17  th game
# Playing  18  th game
# Playing  19  th game
# Playing  20  th game
# Playing  21  th game
# Playing  22  th game
# Playing  23  th game
# Playing  24  th game
# Playing  25  th game
# Playing  26  th game
# Playing  27  th game
# Playing  28  th game
# Playing  29  th game
# Playing  30  th game
# Playing  31  th game
# Playing  32  th game
# Playing  33  th game
# Playing  34  th game
# Playing  35  th game
# Playing  36  th game
# Playing  37  th game
# Playing  38  th game
# Playing  39  th game
# Playing  40  th game
# Playing  41  th game
# Playing  42  th game
# Playing  43  th game
# Playing  44  th game
# Playing  45  th game
# Playing  46  th game
# Playing  47  th game
# Playing  48  th game
# Playing  49  th game
# Playing  50  th game
# Playing  51  th game
# Playing  52  th game
# Playing  53  th game
# Playing  54  th game
# Playing  55  th game
# Playing  56  th game
# Playing  57  th game
# Playing  58  th game
# Playing  59  th game
# Playing  60  th game
# Playing  61  th game
# Playing  62  th game
# Playing  63  th game
# Playing  64  th game
# Playing  65  th game
# Playing  66  th game
# Playing  67  th game
# Playing  68  th game
# Playing  69  th game
# Playing  70  th game
# Playing  71  th game
# Playing  72  th game
# Playing  73  th game
# Playing  74  th game
# Playing  75  th game
# Playing  76  th game
# Playing  77  th game
# Playing  78  th game
# Playing  79  th game
# Playing  80  th game
# Playing  81  th game
# Playing  82  th game
# Playing  83  th game
# Playing  84  th game
# Playing  85  th game
# Playing  86  th game
# Playing  87  th game
# Playing  88  th game
# Playing  89  th game
# Playing  90  th game
# Playing  91  th game
# Playing  92  th game
# Playing  93  th game
# Playing  94  th game
# Playing  95  th game
# Playing  96  th game
# Playing  97  th game
# Playing  98  th game
# Playing  99  th game
# Playing  100  th game
# Playing  101  th game
# Playing  102  th game
# Playing  103  th game
# Playing  104  th game
# Playing  105  th game
# Playing  106  th game
# Playing  107  th game
# Playing  108  th game
# Playing  109  th game
# Playing  110  th game
# Playing  111  th game
# Playing  112  th game
# Playing  113  th game
# Playing  114  th game
# Playing  115  th game
# Playing  116  th game
# Playing  117  th game
# Playing  118  th game
# Playing  119  th game
# Playing  120  th game
# Playing  121  th game
# Playing  122  th game
# Playing  123  th game
# Playing  124  th game
# Playing  125  th game
# Playing  126  th game
# Playing  127  th game
# Playing  128  th game
# Playing  129  th game
# Playing  130  th game
# Playing  131  th game
# Playing  132  th game
# Playing  133  th game
# Playing  134  th game
# Playing  135  th game
# Playing  136  th game
# Playing  137  th game
# Playing  138  th game
# Playing  139  th game
# Playing  140  th game
# Playing  141  th game
# Playing  142  th game
# Playing  143  th game
# Playing  144  th game
# Playing  145  th game
# Playing  146  th game
# Playing  147  th game
# Playing  148  th game
# Playing  149  th game
# Playing  150  th game
# Playing  151  th game
# Playing  152  th game
# Playing  153  th game
# Playing  154  th game
# Playing  155  th game
# Playing  156  th game
# Playing  157  th game
# Playing  158  th game
# Playing  159  th game
# Playing  160  th game
# Playing  161  th game
# Playing  162  th game
# Playing  163  th game
# Playing  164  th game
# Playing  165  th game
# Playing  166  th game
# Playing  167  th game
# Playing  168  th game
# Playing  169  th game
# Playing  170  th game
# Playing  171  th game
# Playing  172  th game
# Playing  173  th game
# Playing  174  th game
# Playing  175  th game
# Playing  176  th game
# Playing  177  th game
# Playing  178  th game
# Playing  179  th game
# Playing  180  th game
# Playing  181  th game
# Playing  182  th game
# Playing  183  th game
# Playing  184  th game
# Playing  185  th game
# Playing  186  th game
# Playing  187  th game
# Playing  188  th game
# Playing  189  th game
# Playing  190  th game
# Playing  191  th game
# Playing  192  th game
# Playing  193  th game
# Playing  194  th game
# Playing  195  th game
# Playing  196  th game
# Playing  197  th game
# Playing  198  th game
# Playing  199  th game
# Playing  200  th game
# Playing  201  th game
# Playing  202  th game
# Playing  203  th game
# Playing  204  th game
# Playing  205  th game
# Playing  206  th game
# Playing  207  th game
# Playing  208  th game
# Playing  209  th game
# Playing  210  th game
# Playing  211  th game
# Playing  212  th game
# Playing  213  th game
# Playing  214  th game
# Playing  215  th game
# Playing  216  th game
# Playing  217  th game
# Playing  218  th game
# Playing  219  th game
# Playing  220  th game
# Playing  221  th game
# Playing  222  th game
# Playing  223  th game
# Playing  224  th game
# Playing  225  th game
# Playing  226  th game
# Playing  227  th game
# Playing  228  th game
# Playing  229  th game
# Playing  230  th game
# Playing  231  th game
# Playing  232  th game
# Playing  233  th game
# Playing  234  th game
# Playing  235  th game
# Playing  236  th game
# Playing  237  th game
# Playing  238  th game
# Playing  239  th game
# Playing  240  th game
# Playing  241  th game
# Playing  242  th game
# Playing  243  th game
# Playing  244  th game
# Playing  245  th game
# Playing  246  th game
# Playing  247  th game
# Playing  248  th game
# Playing  249  th game
# Playing  250  th game
# Playing  251  th game
# Playing  252  th game
# Playing  253  th game
# Playing  254  th game
# Playing  255  th game
# Playing  256  th game
# Playing  257  th game
# Playing  258  th game
# Playing  259  th game
# Playing  260  th game
# Playing  261  th game
# Playing  262  th game
# Playing  263  th game
# Playing  264  th game
# Playing  265  th game
# Playing  266  th game
# Playing  267  th game
# Playing  268  th game
# Playing  269  th game
# Playing  270  th game
# Playing  271  th game
# Playing  272  th game
# Playing  273  th game
# Playing  274  th game
# Playing  275  th game
# Playing  276  th game
# Playing  277  th game
# Playing  278  th game
# Playing  279  th game
# Playing  280  th game
# Playing  281  th game
# Playing  282  th game
# Playing  283  th game
# Playing  284  th game
# Playing  285  th game
# Playing  286  th game
# Playing  287  th game
# Playing  288  th game
# Playing  289  th game
# Playing  290  th game
# Playing  291  th game
# Playing  292  th game
# Playing  293  th game
# Playing  294  th game
# Playing  295  th game
# Playing  296  th game
# Playing  297  th game
# Playing  298  th game
# Playing  299  th game
# Playing  300  th game
# Playing  301  th game
# Playing  302  th game
# Playing  303  th game
# Playing  304  th game
# Playing  305  th game
# Playing  306  th game
# Playing  307  th game
# Playing  308  th game
# Playing  309  th game
# Playing  310  th game
# Playing  311  th game
# Playing  312  th game
# Playing  313  th game
# Playing  314  th game
# Playing  315  th game
# Playing  316  th game
# Playing  317  th game
# Playing  318  th game
# Playing  319  th game
# Playing  320  th game
# Playing  321  th game
# Playing  322  th game
# Playing  323  th game
# Playing  324  th game
# Playing  325  th game
# Playing  326  th game
# Playing  327  th game
# Playing  328  th game
# Playing  329  th game
# Playing  330  th game
# Playing  331  th game
# Playing  332  th game
# Playing  333  th game
# Playing  334  th game
# Playing  335  th game
# Playing  336  th game
# Playing  337  th game
# Playing  338  th game
# Playing  339  th game
# Playing  340  th game
# Playing  341  th game
# Playing  342  th game
# Playing  343  th game
# Playing  344  th game
# Playing  345  th game
# Playing  346  th game
# Playing  347  th game
# Playing  348  th game
# Playing  349  th game
# Playing  350  th game
# Playing  351  th game
# Playing  352  th game
# Playing  353  th game
# Playing  354  th game
# Playing  355  th game
# Playing  356  th game
# Playing  357  th game
# Playing  358  th game
# Playing  359  th game
# Playing  360  th game
# Playing  361  th game
# Playing  362  th game
# Playing  363  th game
# Playing  364  th game
# Playing  365  th game
# Playing  366  th game
# Playing  367  th game
# Playing  368  th game
# Playing  369  th game
# Playing  370  th game
# Playing  371  th game
# Playing  372  th game
# Playing  373  th game
# Playing  374  th game
# Playing  375  th game
# Playing  376  th game
# Playing  377  th game
# Playing  378  th game
# Playing  379  th game
# Playing  380  th game
# Playing  381  th game
# Playing  382  th game
# Playing  383  th game
# Playing  384  th game
# Playing  385  th game
# Playing  386  th game
# Playing  387  th game
# Playing  388  th game
# Playing  389  th game
# Playing  390  th game
# Playing  391  th game
# Playing  392  th game
# Playing  393  th game
# Playing  394  th game
# Playing  395  th game
# Playing  396  th game
# Playing  397  th game
# Playing  398  th game
# Playing  399  th game
# Playing  400  th game
# Playing  401  th game
# Playing  402  th game
# Playing  403  th game
# Playing  404  th game
# Playing  405  th game
# Playing  406  th game
# Playing  407  th game
# Playing  408  th game
# Playing  409  th game
# Playing  410  th game
# Playing  411  th game
# Playing  412  th game
# Playing  413  th game
# Playing  414  th game
# Playing  415  th game
# Playing  416  th game
# Playing  417  th game
# Playing  418  th game
# Playing  419  th game
# Playing  420  th game
# Playing  421  th game
# Playing  422  th game
# Playing  423  th game
# Playing  424  th game
# Playing  425  th game
# Playing  426  th game
# Playing  427  th game
# Playing  428  th game
# Playing  429  th game
# Playing  430  th game
# Playing  431  th game
# Playing  432  th game
# Playing  433  th game
# Playing  434  th game
# Playing  435  th game
# Playing  436  th game
# Playing  437  th game
# Playing  438  th game
# Playing  439  th game
# Playing  440  th game
# Playing  441  th game
# Playing  442  th game
# Playing  443  th game
# Playing  444  th game
# Playing  445  th game
# Playing  446  th game
# Playing  447  th game
# Playing  448  th game
# Playing  449  th game
# Playing  450  th game
# Playing  451  th game
# Playing  452  th game
# Playing  453  th game
# Playing  454  th game
# Playing  455  th game
# Playing  456  th game
# Playing  457  th game
# Playing  458  th game
# Playing  459  th game
# Playing  460  th game
# Playing  461  th game
# Playing  462  th game
# Playing  463  th game
# Playing  464  th game
# Playing  465  th game
# Playing  466  th game
# Playing  467  th game
# Playing  468  th game
# Playing  469  th game
# Playing  470  th game
# Playing  471  th game
# Playing  472  th game
# Playing  473  th game
# Playing  474  th game
# Playing  475  th game
# Playing  476  th game
# Playing  477  th game
# Playing  478  th game
# Playing  479  th game
# Playing  480  th game
# Playing  481  th game
# Playing  482  th game
# Playing  483  th game
# Playing  484  th game
# Playing  485  th game
# Playing  486  th game
# Playing  487  th game
# Playing  488  th game
# Playing  489  th game
# Playing  490  th game
# Playing  491  th game
# Playing  492  th game
# Playing  493  th game
# Playing  494  th game
# Playing  495  th game
# Playing  496  th game
# Playing  497  th game
# Playing  498  th game
# Playing  499  th game
# Playing  500  th game
# Playing  501  th game
# Playing  502  th game
# Playing  503  th game
# Playing  504  th game
# Playing  505  th game
# Playing  506  th game
# Playing  507  th game
# Playing  508  th game
# Playing  509  th game
# Playing  510  th game
# Playing  511  th game
# Playing  512  th game
# Playing  513  th game
# Playing  514  th game
# Playing  515  th game
# Playing  516  th game
# Playing  517  th game
# Playing  518  th game
# Playing  519  th game
# Playing  520  th game
# Playing  521  th game
# Playing  522  th game
# Playing  523  th game
# Playing  524  th game
# Playing  525  th game
# Playing  526  th game
# Playing  527  th game
# Playing  528  th game
# Playing  529  th game
# Playing  530  th game
# Playing  531  th game
# Playing  532  th game
# Playing  533  th game
# Playing  534  th game
# Playing  535  th game
# Playing  536  th game
# Playing  537  th game
# Playing  538  th game
# Playing  539  th game
# Playing  540  th game
# Playing  541  th game
# Playing  542  th game
# Playing  543  th game
# Playing  544  th game
# Playing  545  th game
# Playing  546  th game
# Playing  547  th game
# Playing  548  th game
# Playing  549  th game
# Playing  550  th game
# Playing  551  th game
# Playing  552  th game
# Playing  553  th game
# Playing  554  th game
# Playing  555  th game
# Playing  556  th game
# Playing  557  th game
# Playing  558  th game
# Playing  559  th game
# Playing  560  th game
# Playing  561  th game
# Playing  562  th game
# Playing  563  th game
# Playing  564  th game
# Playing  565  th game
# Playing  566  th game
# Playing  567  th game
# Playing  568  th game
# Playing  569  th game
# Playing  570  th game
# Playing  571  th game
# Playing  572  th game
# Playing  573  th game
# Playing  574  th game
# Playing  575  th game
# Playing  576  th game
# Playing  577  th game
# Playing  578  th game
# Playing  579  th game
# Playing  580  th game
# Playing  581  th game
# Playing  582  th game
# Playing  583  th game
# Playing  584  th game
# Playing  585  th game
# Playing  586  th game
# Playing  587  th game
# Playing  588  th game
# Playing  589  th game
# Playing  590  th game
# Playing  591  th game
# Playing  592  th game
# Playing  593  th game
# Playing  594  th game
# Playing  595  th game
# Playing  596  th game
# Playing  597  th game
# Playing  598  th game
# Playing  599  th game
# Playing  600  th game
# Playing  601  th game
# Playing  602  th game
# Playing  603  th game
# Playing  604  th game
# Playing  605  th game
# Playing  606  th game
# Playing  607  th game
# Playing  608  th game
# Playing  609  th game
# Playing  610  th game
# Playing  611  th game
# Playing  612  th game
# Playing  613  th game
# Playing  614  th game
# Playing  615  th game
# Playing  616  th game
# Playing  617  th game
# Playing  618  th game
# Playing  619  th game
# Playing  620  th game
# Playing  621  th game
# Playing  622  th game
# Playing  623  th game
# Playing  624  th game
# Playing  625  th game
# Playing  626  th game
# Playing  627  th game
# Playing  628  th game
# Playing  629  th game
# Playing  630  th game
# Playing  631  th game
# Playing  632  th game
# Playing  633  th game
# Playing  634  th game
# Playing  635  th game
# Playing  636  th game
# Playing  637  th game
# Playing  638  th game
# Playing  639  th game
# Playing  640  th game
# Playing  641  th game
# Playing  642  th game
# Playing  643  th game
# Playing  644  th game
# Playing  645  th game
# Playing  646  th game
# Playing  647  th game
# Playing  648  th game
# Playing  649  th game
# Playing  650  th game
# Playing  651  th game
# Playing  652  th game
# Playing  653  th game
# Playing  654  th game
# Playing  655  th game
# Playing  656  th game
# Playing  657  th game
# Playing  658  th game
# Playing  659  th game
# Playing  660  th game
# Playing  661  th game
# Playing  662  th game
# Playing  663  th game
# Playing  664  th game
# Playing  665  th game
# Playing  666  th game
# Playing  667  th game
# Playing  668  th game
# Playing  669  th game
# Playing  670  th game
# Playing  671  th game
# Playing  672  th game
# Playing  673  th game
# Playing  674  th game
# Playing  675  th game
# Playing  676  th game
# Playing  677  th game
# Playing  678  th game
# Playing  679  th game
# Playing  680  th game
# Playing  681  th game
# Playing  682  th game
# Playing  683  th game
# Playing  684  th game
# Playing  685  th game
# Playing  686  th game
# Playing  687  th game
# Playing  688  th game
# Playing  689  th game
# Playing  690  th game
# Playing  691  th game
# Playing  692  th game
# Playing  693  th game
# Playing  694  th game
# Playing  695  th game
# Playing  696  th game
# Playing  697  th game
# Playing  698  th game
# Playing  699  th game
# Playing  700  th game
# Playing  701  th game
# Playing  702  th game
# Playing  703  th game
# Playing  704  th game
# Playing  705  th game
# Playing  706  th game
# Playing  707  th game
# Playing  708  th game
# Playing  709  th game
# Playing  710  th game
# Playing  711  th game
# Playing  712  th game
# Playing  713  th game
# Playing  714  th game
# Playing  715  th game
# Playing  716  th game
# Playing  717  th game
# Playing  718  th game
# Playing  719  th game
# Playing  720  th game
# Playing  721  th game
# Playing  722  th game
# Playing  723  th game
# Playing  724  th game
# Playing  725  th game
# Playing  726  th game
# Playing  727  th game
# Playing  728  th game
# Playing  729  th game
# Playing  730  th game
# Playing  731  th game
# Playing  732  th game
# Playing  733  th game
# Playing  734  th game
# Playing  735  th game
# Playing  736  th game
# Playing  737  th game
# Playing  738  th game
# Playing  739  th game
# Playing  740  th game
# Playing  741  th game
# Playing  742  th game
# Playing  743  th game
# Playing  744  th game
# Playing  745  th game
# Playing  746  th game
# Playing  747  th game
# Playing  748  th game
# Playing  749  th game
# Playing  750  th game
# Playing  751  th game
# Playing  752  th game
# Playing  753  th game
# Playing  754  th game
# Playing  755  th game
# Playing  756  th game
# Playing  757  th game
# Playing  758  th game
# Playing  759  th game
# Playing  760  th game
# Playing  761  th game
# Playing  762  th game
# Playing  763  th game
# Playing  764  th game
# Playing  765  th game
# Playing  766  th game
# Playing  767  th game
# Playing  768  th game
# Playing  769  th game
# Playing  770  th game
# Playing  771  th game
# Playing  772  th game
# Playing  773  th game
# Playing  774  th game
# Playing  775  th game
# Playing  776  th game
# Playing  777  th game
# Playing  778  th game
# Playing  779  th game
# Playing  780  th game
# Playing  781  th game
# Playing  782  th game
# Playing  783  th game
# Playing  784  th game
# Playing  785  th game
# Playing  786  th game
# Playing  787  th game
# Playing  788  th game
# Playing  789  th game
# Playing  790  th game
# Playing  791  th game
# Playing  792  th game
# Playing  793  th game
# Playing  794  th game
# Playing  795  th game
# Playing  796  th game
# Playing  797  th game
# Playing  798  th game
# Playing  799  th game
# Playing  800  th game
# Playing  801  th game
# Playing  802  th game
# Playing  803  th game
# Playing  804  th game
# Playing  805  th game
# Playing  806  th game
# Playing  807  th game
# Playing  808  th game
# Playing  809  th game
# Playing  810  th game
# Playing  811  th game
# Playing  812  th game
# Playing  813  th game
# Playing  814  th game
# Playing  815  th game
# Playing  816  th game
# Playing  817  th game
# Playing  818  th game
# Playing  819  th game
# Playing  820  th game
# Playing  821  th game
# Playing  822  th game
# Playing  823  th game
# Playing  824  th game
# Playing  825  th game
# Playing  826  th game
# Playing  827  th game
# Playing  828  th game
# Playing  829  th game
# Playing  830  th game
# Playing  831  th game
# Playing  832  th game
# Playing  833  th game
# Playing  834  th game
# Playing  835  th game
# Playing  836  th game
# Playing  837  th game
# Playing  838  th game
# Playing  839  th game
# Playing  840  th game
# Playing  841  th game
# Playing  842  th game
# Playing  843  th game
# Playing  844  th game
# Playing  845  th game
# Playing  846  th game
# Playing  847  th game
# Playing  848  th game
# Playing  849  th game
# Playing  850  th game
# Playing  851  th game
# Playing  852  th game
# Playing  853  th game
# Playing  854  th game
# Playing  855  th game
# Playing  856  th game
# Playing  857  th game
# Playing  858  th game
# Playing  859  th game
# Playing  860  th game
# Playing  861  th game
# Playing  862  th game
# Playing  863  th game
# Playing  864  th game
# Playing  865  th game
# Playing  866  th game
# Playing  867  th game
# Playing  868  th game
# Playing  869  th game
# Playing  870  th game
# Playing  871  th game
# Playing  872  th game
# Playing  873  th game
# Playing  874  th game
# Playing  875  th game
# Playing  876  th game
# Playing  877  th game
# Playing  878  th game
# Playing  879  th game
# Playing  880  th game
# Playing  881  th game
# Playing  882  th game
# Playing  883  th game
# Playing  884  th game
# Playing  885  th game
# Playing  886  th game
# Playing  887  th game
# Playing  888  th game
# Playing  889  th game
# Playing  890  th game
# Playing  891  th game
# Playing  892  th game
# Playing  893  th game
# Playing  894  th game
# Playing  895  th game
# Playing  896  th game
# Playing  897  th game
# Playing  898  th game
# Playing  899  th game
# Playing  900  th game
# Playing  901  th game
# Playing  902  th game
# Playing  903  th game
# Playing  904  th game
# Playing  905  th game
# Playing  906  th game
# Playing  907  th game
# Playing  908  th game
# Playing  909  th game
# Playing  910  th game
# Playing  911  th game
# Playing  912  th game
# Playing  913  th game
# Playing  914  th game
# Playing  915  th game
# Playing  916  th game
# Playing  917  th game
# Playing  918  th game
# Playing  919  th game
# Playing  920  th game
# Playing  921  th game
# Playing  922  th game
# Playing  923  th game
# Playing  924  th game
# Playing  925  th game
# Playing  926  th game
# Playing  927  th game
# Playing  928  th game
# Playing  929  th game
# Playing  930  th game
# Playing  931  th game
# Playing  932  th game
# Playing  933  th game
# Playing  934  th game
# Playing  935  th game
# Playing  936  th game
# Playing  937  th game
# Playing  938  th game
# Playing  939  th game
# Playing  940  th game
# Playing  941  th game
# Playing  942  th game
# Playing  943  th game
# Playing  944  th game
# Playing  945  th game
# Playing  946  th game
# Playing  947  th game
# Playing  948  th game
# Playing  949  th game
# Playing  950  th game
# Playing  951  th game
# Playing  952  th game
# Playing  953  th game
# Playing  954  th game
# Playing  955  th game
# Playing  956  th game
# Playing  957  th game
# Playing  958  th game
# Playing  959  th game
# Playing  960  th game
# Playing  961  th game
# Playing  962  th game
# Playing  963  th game
# Playing  964  th game
# Playing  965  th game
# Playing  966  th game
# Playing  967  th game
# Playing  968  th game
# Playing  969  th game
# Playing  970  th game
# Playing  971  th game
# Playing  972  th game
# Playing  973  th game
# Playing  974  th game
# Playing  975  th game
# Playing  976  th game
# Playing  977  th game
# Playing  978  th game
# Playing  979  th game
# Playing  980  th game
# Playing  981  th game
# Playing  982  th game
# Playing  983  th game
# Playing  984  th game
# Playing  985  th game
# Playing  986  th game
# Playing  987  th game
# Playing  988  th game
# Playing  989  th game
# Playing  990  th game
# Playing  991  th game
# Playing  992  th game
# Playing  993  th game
# Playing  994  th game
# Playing  995  th game
# Playing  996  th game
# Playing  997  th game
# Playing  998  th game
# Playing  999  th game
# ---------------------------------------------------------------------------
# HangmanAPIError                           Traceback (most recent call last)
# Cell In[8], line 4
#       2 print('Playing ', i, ' th game')
#       3 # Uncomment the following line to execute your final runs. Do not do this until you are satisfied with your submission
# ----> 4 api.start_game(practice=0,verbose=False)
#       6 # DO NOT REMOVE as otherwise the server may lock you out for too high frequency of requests
#       7 time.sleep(0.5)
#
# Cell In[2], line 74, in HangmanAPI.start_game(self, practice, verbose)
#      70 def start_game(self, practice=True, verbose=True):
#      71     # reset guessed letters to empty set and current plausible dictionary to the full dictionary
#      72     self.guessed_letters = []
# ---> 74     response = self.request("/new_game", {"practice":practice})
#      75     if response.get('status')=="approved":
#      76         game_id = response.get('game_id')
#
# Cell In[2], line 177, in HangmanAPI.request(self, path, args, post_args, method)
#     174     raise HangmanAPIError('Maintype was not text, or querystring')
#     176 if result and isinstance(result, dict) and result.get("error"):
# --> 177     raise HangmanAPIError(result)
#     178 return result
#
# HangmanAPIError: {'error': 'You have reached 1000 of games', 'status': 'denied'}

# %% [markdown]
# ## To check your game statistics
# 1. Simply use "my_status" method.
# 2. Returns your total number of games, and number of wins.

# %%
[total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes] = api.my_status() # Get my game stats: (# of tries, # of wins)
print(total_practice_runs,total_recorded_runs,total_recorded_successes,total_practice_successes)
success_rate = total_recorded_successes/total_recorded_runs
print('overall success rate = %.3f' % success_rate)
# Out:
# 204 1000 627 137
# overall success rate = 0.627
